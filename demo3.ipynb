# %%
import pandas as pd
import numpy as np
filepath="D:\Python\pandas\pandas\含钢量test.xlsx"
data=pd.read_excel(filepath,sheet_name="钢筋工程量",header=None)

# %% [markdown]
# 读取excel 对excel表进行数据的清洗，处理缺省值 data.dropna(axis="index"，how="all"，inplace=True) 将所有值为nan的行删除
# data.dropna(axis="columns"，how="all"，inplace=True) 将所有值为nan的columns删除

# %%
data.loc[0,:]=data.loc[0,:].fillna(method='ffill')
data

#mask = data.loc[0,:].applymap(lambda x: 1 if "unnamed" in str(x) else 0)
#print(mask)

# %% [markdown]
# pandas

# %%
data.loc[:,[0,1]]=data.loc[:,[0,1]].fillna(method='ffill')
data

# %%
data=data.fillna(0)
data

# %%
data=data[~data[1].str.contains("合计")]
data
# Out:
#     0    1        2        3        4         5        6        7        8   \
# 0   类别   层号   面积(m2)   HPB300   HRB400    HRB400   HRB400   HRB400   HRB400
# 1   类别   层号        0        6        6       8.0     10.0     12.0     14.0
# 2    梁  第1层  1733.22        0   656.26   8526.01  5287.36  1524.81   929.81
# 3    梁  第2层   661.11        0   133.82   2217.23    771.5    294.0    67.34
# 4    梁  第3层   658.24        0    93.91   1452.93  1017.46   329.75    13.35
# 5    梁  第4层   406.79        0    71.26   1120.45   683.83   240.35    52.46
# 6    梁  第5层   406.79        0    73.08   1005.03   828.53   178.66    81.68
# 7    梁  第6层   500.82        0    67.47   2299.96   559.73   657.76   113.76
# 10   柱  第1层  1733.22        0        0   2483.52        0        0        0
# 11   柱  第2层   661.11        0        0    425.45    70.29        0        0
# 12   柱  第3层   658.24        0        0    348.48        0        0        0
# ...

# %%
data.loc[]
